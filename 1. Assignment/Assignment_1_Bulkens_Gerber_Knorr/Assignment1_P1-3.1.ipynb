# %% [markdown]
# ### Team Members: Björn Bulkens, Klemens Gerber, Daniel M. Knorr

# %%
import time
import PyPDF2

#-----------------
#bahnstadt.txt mit PyPDF2
#-----------------

directoryPathSource = './bahnstadt.pdf'
directoryPathDestination = './bahnstadt_PyPDF2.txt'

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()


#-----------------
#bahnstadt.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './bahnstadt.pdf'
directoryPathDestination = './bahnstadt_plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Xref table not zero-indexed. ID numbers for objects will be corrected.
# Laufzeit PyPDF2:  1.9499781131744385
# Laufzeit Plumber:  5.483238935470581

# %%
import time
import PyPDF2

directoryPathSource = './bundeswehr.pdf'
directoryPathDestination = './bundeswehr_PyPDF2.txt'

#-----------------
#bundeswehr.txt mit PyPDF2
#-----------------

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()

#-----------------
#bundeswehr.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './bundeswehr.pdf'
directoryPathDestination = './bundeswehr_plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Laufzeit PyPDF2:  1.7027146816253662
# Laufzeit Plumber:  6.81497597694397

# %%
import time
import PyPDF2

directoryPathSource = './wegweiser_senioren.pdf'
directoryPathDestination = './wegweiser_senioren_PyPDF2.txt'

#-----------------
#wegweiser_senioren.txt mit PyPDF2
#-----------------

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()

#-----------------
#wegweiser_senioren.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './wegweiser_senioren.pdf'
directoryPathDestination = './wegweiser_senioren_plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Laufzeit PyPDF2:  1.4086577892303467
# Laufzeit Plumber:  3.4335579872131348

# %%
import PyPDF2
import time

directoryPathSource = './liste1.pdf'
directoryPathDestination = './liste1_PyPDF2.txt'

#-----------------
#liste1.txt mit PyPDF2
#-----------------

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()

#-----------------
#liste1.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './liste1.pdf'
directoryPathDestination = './liste1_Plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Laufzeit PyPDF2:  0.055828094482421875
# Laufzeit Plumber:  0.13448405265808105

# %%
import time
import PyPDF2

directoryPathSource = './double_ocr.pdf'
directoryPathDestination = './double_ocr_PyPDF.txt'

#-----------------
#double_ocr.txt mit PyPDF2
#-----------------

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()

#-----------------
#double_ocr.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './double_ocr.pdf'
directoryPathDestination = './double_ocr_plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Laufzeit PyPDF2:  0.11333775520324707
# Laufzeit Plumber:  0.15613603591918945

# %%
import time
import PyPDF2

directoryPathSource = './single_ocr.pdf'
directoryPathDestination = './single_ocr_PyPDF.txt'

#-----------------
#single_ocr.txt mit PyPDF2
#-----------------

file = open(directoryPathDestination, 'w')

begin = time.time()

with open(directoryPathSource, mode='rb') as pdf:
    pdfReader = PyPDF2.PdfFileReader(pdf)
    for page in pdfReader.pages:
        text = page.extractText()
        file.write(text)

end = time.time()

print("Laufzeit PyPDF2: ", end-begin)

file.close()
pdf.close()

#-----------------
#single_ocr.txt mit Plumber
#-----------------

import pdfplumber

directoryPathSource = './single_ocr.pdf'
directoryPathDestination = './single_ocr_plumber.txt'

file = open(directoryPathDestination,"w")

begin = time.time()

with pdfplumber.open(directoryPathSource) as pdf:
    for pages in pdf.pages:
        text = pages.extract_text()
        file.write(text)

end = time.time()

print("Laufzeit Plumber: ", end-begin)

file.close()
pdf.close()
# Out:
# Laufzeit PyPDF2:  0.3277308940887451
# Laufzeit Plumber:  0.33283090591430664

# %%
import pdfplumber
import pandas as pd

directoryPathSource = './bundeswehr.pdf'

file = open('bundeswehr_daten.txt', 'w')

#-----------------
#bundeswehr.txt mit Plumber and Panda
#-----------------

with pdfplumber.open(directoryPathSource) as pdf:
    for page in pdf.pages:
        table = page.extract_table()
        #Hier werden nur die Spalten Telefon, Telefon(IVBB) und E-Mail und URL berücksichtigt!
        #Faxnummern werden nicht berücksichtigt
        pdframe = pd.DataFrame(table[1::], columns=table[0])
        df1 = pd.DataFrame(pdframe, columns=['Telefon', 'Telefon(IV\nBB)', 'E-Mail und URL'])
        for column in ['Telefon', 'Telefon(IV\nBB)', 'E-Mail und URL']:
            df1[column] = df1[column].str.replace("\n", "")
        file.write(df1.to_string(index=False, header=False))

file.close()

# %%
import difflib

#####
markierterText_acrobat = open('bahnstadtAdobeAcrobatReaderAllesMarkiert.txt', 'rb')
with markierterText_acrobat as markierterText_acrobat:
    markierterText_txt_acrobat = markierterText_acrobat.readlines()

#####
plumber_in = open('bahnstadt_plumber.txt', 'rb')
with plumber_in as text_file_plumber:
    plumber_txt = text_file_plumber.readlines()

#####
pypdf_in = open('bahnstadt_PyPDF2.txt', 'rb')
with pypdf_in as text_file_pypdf:
    pypdf_txt = text_file_pypdf.readlines()

#####
temp = difflib.SequenceMatcher(None, plumber_txt, pypdf_txt)

#print(temp.get_matching_blocks())
print('Quick ratio: ', temp.quick_ratio())
print('Similarity Score: ', temp.ratio())

text_file_pypdf.close()
text_file_plumber.close()
markierterText_acrobat.close()

# Vergleich

print('Vergleich manuell kopiert aus Acrobat Reader mit Plumber  : ', difflib.SequenceMatcher(None, plumber_txt, markierterText_txt_acrobat).ratio())

print('Vergleich manuell kopiert aus Acrobat Reader mit PyPDF2  : ', difflib.SequenceMatcher(None, pypdf_txt, markierterText_txt_acrobat).ratio())
# Out:
# Quick ratio:  0.22821397756686798
# Similarity Score:  0.12338222605694564
# Vergleich manuell kopiert aus Acrobat Reader mit Plumber  :  0.053019145802650956
# Vergleich manuell kopiert aus Acrobat Reader mit PyPDF2  :  0.2624078624078624
